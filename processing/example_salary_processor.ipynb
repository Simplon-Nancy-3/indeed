# %%
import pandas as pd
from processing import SalaryProcessor
df = pd.read_csv('indeed.csv')
SalaryProcessor().process_dataframe(df, 'salary')
# Out:
#                    _id                              query  \
# 0     c5bc824b51725453                 ["data+scientist"]
# 1     41984177da7622eb  ["data+analyst","data+scientist"]
# 2     ecdbb413df0fc6d6                 ["data+scientist"]
# 3     51c591314452c91c   ["data+scientist","developpeur"]
# 4     1c8dce698e6095b3                 ["data+scientist"]
# ...                ...                                ...
# 2997  d44dfcd528c42015                    ["developpeur"]
# 2998  7568ea22f2b4d677                    ["developpeur"]
# 2999  73802c42e64bdec8                    ["developpeur"]
# 3000  2f395cc64632fb9a                    ["developpeur"]
# 3001  e019b89bfa767501                    ["developpeur"]
#
#                                                   title  \
# 0                       Alternance - Data Scientist H/F
# 1                                      DATA ANALYST H/F
# 2              Alternance - Data Scientist - Metz (F/H)
# ...
