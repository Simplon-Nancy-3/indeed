# %%
import pandas as pd
import numpy as np
from processing import processing

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid', {'legend.frameon':True})

# %%
def make_csv(pl, path, name, suffix='process'):
    pl.fit_transform(pd.read_csv('{}{}.csv'.format(path, name))).to_csv('{}{}_{}.csv'.format(path, name, suffix), index=False, encoding='utf-8')

# %%
make_csv(processing.indeed_pl, 'csv/', 'jobs_it')
# make_csv(processing.indeed_pl, 'csv/', 'jobs_ing')
# make_csv(processing.indeed_pl, 'csv/', 'jobs_rh')
# make_csv(processing.indeed_pl, 'csv/', 'jobs_com')
# Out:
# [Pipeline]  (step 1 of 9) Processing salary_transformer, total=   0.1s
# [Pipeline] .. (step 2 of 9) Processing date_transformer, total=   0.1s
# [Pipeline] .. (step 3 of 9) Processing query_transfomer, total=   0.1s
# [Pipeline]  (step 4 of 9) Processing contract_transformer, total=   0.1s
# [Pipeline]  (step 5 of 9) Processing rating_mean_transformer, total=   0.0s
# [Pipeline]  (step 6 of 9) Processing rating_count_transformer, total=   0.0s
# [Pipeline]  (step 7 of 9) Processing location_transformer, total=   0.0s
# [Pipeline]  (step 8 of 9) Processing sponso_transformer, total=   0.0s
# [Pipeline] ..... (step 9 of 9) Processing salary_bander, total=   0.1s

# %%
df = pd.read_csv('csv/jobs_it_process.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10362 entries, 0 to 10361
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   _id                          10362 non-null  object
#  1   query                        10362 non-null  object
#  2   title                        10362 non-null  object
#  3   company                      10361 non-null  object
#  4   rating_mean                  10362 non-null  float64
#  5   location                     10362 non-null  object
#  6   salary                       1546 non-null   object
#  7   summary                      10362 non-null  object
#  8   sponso                       10362 non-null  int64
#  9   contract                     7038 non-null   object
#  10  desc                         10362 non-null  object
#  11  rating_count                 10362 non-null  int64
#  12  day_since                    10362 non-null  object
# ...

# %%
df[df['salary_mean'].isnull() == False].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1541 entries, 5 to 10351
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   _id                          1541 non-null   object
#  1   query                        1541 non-null   object
#  2   title                        1541 non-null   object
#  3   company                      1541 non-null   object
#  4   rating_mean                  1541 non-null   float64
#  5   location                     1541 non-null   object
#  6   salary                       1541 non-null   object
#  7   summary                      1541 non-null   object
#  8   sponso                       1541 non-null   int64
#  9   contract                     1283 non-null   object
#  10  desc                         1541 non-null   object
#  11  rating_count                 1541 non-null   int64
#  12  day_since                    1541 non-null   object
# ...

# %%
df[df['dep'].isnull()]['location'].unique()
# Out:
# array(['France', 'Télétravail', 'Île-de-France', 'false', 'Vienne 86',
#        'Auvergne-Rhône-Alpes', 'Nouvelle-Aquitaine', 'Pays de la Loire',
#        'Occitanie', 'Bourgogne-Franche-Comté', 'Bretagne',
#        'Centre-Val de Loire', 'Grand Est', "L'Ave Maria",
#        'Hauts-de-France', 'Normandie', "Provence-Alpes-Côte d'Azur"],
#       dtype=object)

# %%
df['query_data+scientist'].hist()

# %%
for i in df[df['dep'].isnull()]['location']:
    print(i)
# Out:
# France
# France
# France
# France
# France
# Télétravail
# France
# France
# France
# Télétravail
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# Télétravail
# France
# France
# France
# France
# Île-de-France
# France
# France
# France
# Île-de-France
# France
# France
# France
# France
# France
# Île-de-France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# France
# false
# Télétravail
# France
# France
# France
# France
# France
# France
# France
# France
# false
# France
# France
# France
# France
# France
# ...
